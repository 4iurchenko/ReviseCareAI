# %%
GMAP_API_KEY = ""

AZURE_OPEN_AI_KEY = ''
AZURE_OPEN_AI_ENDPOINT = ''

#Skip OPENAI_API_KEY if you use AZURE_OPEN_AI_KEY
OPENAI_API_KEY = ""

print("Variables GMAP_API_KEY, OPENAI_API_KEY, AZURE_OPEN_AI_KEY, AZURE_OPEN_AI_ENDPOINT were initialized")
